# %%
import wget
import os
import shutil
import zipfile
from tqdm import tqdm
import copy

# %% [markdown]
# # Download Data

# %%
if os.path.isfile('../RockPapersScissor/rockpaperscissors.zip') :    
    print('file sudah ada')
else:
    wget.download(
        'https://dicodingacademy.blob.core.windows.net/picodiploma/ml_pemula_academy/rockpaperscissors.zip' , 
        '../RockPapersScissor'
    )
# Out:
# file sudah ada

# %% [markdown]
# # Ekstrak data

# %%
if os.path.exists('../RockPapersScissor/rockpaperscissors'):
    print('File Sudah Terekstrak Sebelumnya')
else:
    pass
    #Ekstrak data 
    lokasi_file_zip = '../RockPapersScissor/rockpaperscissors.zip'
    zip_file = zipfile.ZipFile(lokasi_file_zip,mode='r')
    zip_file.extractall('../RockPapersScissor')
    zip_file.close()
    print('Ekstrak berhasil')
# Out:
# File Sudah Terekstrak Sebelumnya

# %%
#Menyiapkan Lokasi
lokasi_kertas = '..\\RockPapersScissor\\rockpaperscissors\\paper'
lokasi_batu = '..\\RockPapersScissor\\rockpaperscissors\\rock'
lokasi_gunting = '..\\RockPapersScissor\\rockpaperscissors\\scissors'

# %%
#Dengan Porsi 80% untuk train dan 20% untuk validation

#Membuah Masing masing data menjadi list dan dimasukan ke variabel
kertas = os.listdir(lokasi_kertas)
gunting = os.listdir(lokasi_gunting)
batu = os.listdir(lokasi_batu)

# %%
import random
random.seed(0)

# %%
a = random.randint(a=0, b=3)
a
# Out:
# 3

# %%
def pisah_data(data, train_size=0.8):

    """Fungsi ini untuk memisahkan data menjadi train set dan validation_set
    dengan urutan hasil return : data_train, data_validasi"""
    test_size = 1 - train_size
    data_backup = copy.deepcopy(data)
    n_train = int(train_size * len(data_backup))
    n_test  = int(test_size  * len(data_backup))
    
    selisih =len(data_backup) - (n_train + n_test)
    print(len(data_backup), " - ( ",n_train, " + ", n_test," ) = ",selisih)
    if selisih > 0:
        n_test +=selisih

    train = []
    #memilih data train dari data
    while len(train) != n_train:
        bantu = random.randint(0, (len(data_backup)-1))
        if data_backup[bantu] not in train:
            train.append(data_backup[bantu])
            del data_backup[bantu]

    #Sisanya Dicopy kedalam Train
    test = copy.deepcopy(data_backup)
    del data_backup
    
    print("Panjang train : ",n_train)
    print("Panjang test : ",n_test,"\n")
    return train, test

# %%
train_kertas, test_kertas = pisah_data(kertas)
train_gunting, test_gunting = pisah_data(gunting)
train_batu, test_batu = pisah_data(batu)
# Out:
# 0  - (  0  +  0  ) =  0
# Panjang train :  0
# Panjang test :  0
#
# 0  - (  0  +  0  ) =  0
# Panjang train :  0
# Panjang test :  0
#
# 0  - (  0  +  0  ) =  0
# Panjang train :  0
# Panjang test :  0

# %%
#Selanjutnya pindahkan ke folder terpisah

#Membuat fungsi untuk membuat folder penyimpanan dan memindahkan data yang telah dipisahkan kedalam folder tersebut
def cd_data(data_train, data_test, data_path, train_path, test_path):
    """Fungsi ini untuk membuat folder penyimpanan dan 
    memasukan data yang telah dipisahkan dengan folder tersebut"""
      
    #Memeriksa apakan folder sudah ada, jika belum maka tambahkan folder
    if not (os.path.exists(train_path) and os.path.exists(test_path)):
        os.makedirs(train_path)
        os.makedirs(test_path)
      
    #memindahkan ke folder terpisah
    for i in range(len(data_train)):
        shutil.move(os.path.join(data_path, data_train[i]), os.path.join(train_path, data_train[i]))
      
    #memindahkan ke folder terpisah
    for i in range(len(data_test)):
        shutil.move(os.path.join(data_path, data_test[i]), os.path.join(test_path, data_test[i]))

# %%
#Buat lokasi train dan validation
lokasi_train_set = '..\\RockPapersScissor\\data\\train'
lokasi_test_set = '..\\RockPapersScissor\\data\\test'

# %%
label_dict = {
    'paper': (train_kertas, test_kertas, lokasi_kertas),
    'rock': (train_batu, test_batu, lokasi_batu),
    'scissors': (train_gunting, test_gunting, lokasi_gunting)
}

# %% [markdown]
# for i, j in label_dict.items():
#     print(j[0])
#     print("===================================================================")

# %%
if os.path.exists(lokasi_train_set and lokasi_test_set):
    print('Folder Sudah ada')
else:
    for label, value in label_dict.items():
        #print(label)
        #print(value[0][0:10])
        #print(value[1][0:10])
        #print(os.path.join(lokasi_train_set,label))
        #print(os.path.join(lokasi_test_set,label))
        #print("="*100)
        cd_data(
            value[0],
            value[1],
            value[2],
            os.path.join(lokasi_train_set,label),
            os.path.join(lokasi_test_set,label)
        )
        
    #cd_data(
    #  train_kertas,
    #  test_kertas,
    #  lokasi_kertas,
    #  os.path.join(lokasi_train_set,'paper'),
    #  os.path.join(lokasi_test_set,'paper')
    #)
    #
    #cd_data(
    #  train_batu,
    #  test_batu,
    #  lokasi_batu,
    #  os.path.join(lokasi_train_set,'rock'),
    #  os.path.join(lokasi_test_set,'rock')
    #)
    #
    #cd_data(
    #  train_gunting,
    #  test_gunting,
    #  lokasi_gunting,
    #  os.path.join(lokasi_train_set,'scissors'),
    #  os.path.join(lokasi_test_set,'scissors')
    #)
# Out:
# Folder Sudah ada

# %%
os.path.join(lokasi_test_set,'rock')
# Out:
# '..\\RockPapersScissor\\data\\test\\rock'

# %%
import torch
from torch import nn, optim
from jcopdl.callback import Callback, set_config

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda', index=0)

# %% [markdown]
# # Dataset & dataloader

# %%
from torchvision import datasets, transforms
from torch.utils.data import DataLoader

# %%
bs = 128
crop_size = 128

train_transform = transforms.Compose([
    transforms.RandomRotation(15),
    transforms.RandomResizedCrop(crop_size, scale=(0.8, 1.0)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomVerticalFlip(),
    transforms.ToTensor()
])

test_transform = transforms.Compose([
    transforms.Resize(140),
    transforms.CenterCrop(crop_size),
    transforms.ToTensor()
])

train_set = datasets.ImageFolder("data/train/", transform=train_transform)
trainloader = DataLoader(train_set, batch_size=bs, shuffle=True, num_workers=4)

test_set = datasets.ImageFolder("data/test/", transform=test_transform)
testloader = DataLoader(test_set, batch_size=bs, shuffle=True)

# %%
feature, target = next(iter(trainloader))
feature.shape
# Out:
# torch.Size([128, 3, 128, 128])

# %%
label = train_set.classes
label
# Out:
# ['paper', 'rock', 'scissors']

# %% [markdown]
# # Arsitektur & Config

# %%
from jcopdl.layers import conv_block, linear_block

# %%
128*4*4
# Out:
# 2048

# %%
class CNN(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv = nn.Sequential(
            conv_block(3, 8),
            conv_block(8, 16), 
            conv_block(16, 32),
            conv_block(32, 64),
            conv_block(64, 128), 
            nn.Flatten()
        )
        
        self.fc = nn.Sequential(
            linear_block(2048, 1024, dropout=0.2),
            linear_block(1024, 512, dropout=0.2),
            linear_block(512, 256, dropout=0.2),
            linear_block(256, 3, activation="lsoftmax")
        )
        
    def forward(self, x):
        x = self.conv(x)
        x = self.fc(x)
        return x

# %%
config = set_config({
    "batch_size": bs,
    "crop_size": crop_size
})

# %% [markdown]
# # Training Preparation -> MCOC

# %%
model = CNN().to(device)
criterion = nn.NLLLoss()
optimizer = optim.AdamW(model.parameters(), lr=0.001)
callback = Callback(model, config, outdir="model")

# %% [markdown]
# # Training

# %%
from tqdm.auto import tqdm

def loop_fn(mode, dataset, dataloader, model, criterion, optimizer, device):
    if mode == "train":
        model.train()
    elif mode == "test":
        model.eval()
    cost = correct = 0
    for feature, target in tqdm(dataloader, desc=mode.title()):
        feature, target = feature.to(device), target.to(device)
        output = model(feature)
        loss = criterion(output, target)
        
        if mode == "train":
            loss.backward()
            optimizer.step()
            optimizer.zero_grad()
        
        cost += loss.item() * feature.shape[0]
        correct += (output.argmax(1) == target).sum().item()
    cost = cost / len(dataset)
    acc = correct / len(dataset)
    return cost, acc

# %%
while True:
    train_cost, train_score = loop_fn("train", train_set, trainloader, model, criterion, optimizer, device)
    with torch.no_grad():
        test_cost, test_score = loop_fn("test", test_set, testloader, model, criterion, optimizer, device)
    
    # Logging
    callback.log(train_cost, test_cost, train_score, test_score)

    # Checkpoint
    callback.save_checkpoint()
        
    # Runtime Plotting
    callback.cost_runtime_plotting()
    callback.score_runtime_plotting()
    
    # Early Stopping
    if callback.early_stopping(model, monitor="test_score"):
        callback.plot_cost()
        callback.plot_score()
        break
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Train', max=14.0, style=ProgressStyle(description_width='…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=4.0, style=ProgressStyle(description_width='in…
# Epoch     1
# Train_cost  = 1.1000 | Test_cost  = 1.0984 | Train_score = 0.3419 | Test_score = 0.3417 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=14.0, style=ProgressStyle(description_width='…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=4.0, style=ProgressStyle(description_width='in…
# Epoch     2
# Train_cost  = 1.0985 | Test_cost  = 1.0981 | Train_score = 0.3282 | Test_score = 0.3326 |
# ==> EarlyStop patience =  1 | Best test_score: 0.3417
# HBox(children=(FloatProgress(value=0.0, description='Train', max=14.0, style=ProgressStyle(description_width='…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=4.0, style=ProgressStyle(description_width='in…
# Epoch     3
# Train_cost  = 1.0972 | Test_cost  = 1.0879 | Train_score = 0.3482 | Test_score = 0.3485 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=14.0, style=ProgressStyle(description_width='…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=4.0, style=ProgressStyle(description_width='in…
# Epoch     4
# Train_cost  = 1.0559 | Test_cost  = 1.0191 | Train_score = 0.4322 | Test_score = 0.5057 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=14.0, style=ProgressStyle(description_width='…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=4.0, style=ProgressStyle(description_width='in…
# Epoch     5
# Train_cost  = 0.9416 | Test_cost  = 0.8860 | Train_score = 0.5506 | Test_score = 0.5945 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=14.0, style=ProgressStyle(description_width='…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=4.0, style=ProgressStyle(description_width='in…
# Epoch     6
# Train_cost  = 0.7639 | Test_cost  = 0.8624 | Train_score = 0.6169 | Test_score = 0.5330 |
# ==> EarlyStop patience =  1 | Best test_score: 0.5945
# HBox(children=(FloatProgress(value=0.0, description='Train', max=14.0, style=ProgressStyle(description_width='…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=4.0, style=ProgressStyle(description_width='in…
# Epoch     7
# Train_cost  = 0.5254 | Test_cost  = 0.8721 | Train_score = 0.7879 | Test_score = 0.6811 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=14.0, style=ProgressStyle(description_width='…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=4.0, style=ProgressStyle(description_width='in…
# Epoch     8
# Train_cost  = 0.4281 | Test_cost  = 0.5502 | Train_score = 0.8359 | Test_score = 0.7677 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=14.0, style=ProgressStyle(description_width='…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=4.0, style=ProgressStyle(description_width='in…
# Epoch     9
# Train_cost  = 0.2834 | Test_cost  = 0.4159 | Train_score = 0.8977 | Test_score = 0.8337 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=14.0, style=ProgressStyle(description_width='…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=4.0, style=ProgressStyle(description_width='in…
# Epoch    10
# Train_cost  = 0.2147 | Test_cost  = 0.4060 | Train_score = 0.9211 | Test_score = 0.8360 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=14.0, style=ProgressStyle(description_width='…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=4.0, style=ProgressStyle(description_width='in…
# Epoch    11
# Train_cost  = 0.1352 | Test_cost  = 0.2336 | Train_score = 0.9543 | Test_score = 0.9203 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=14.0, style=ProgressStyle(description_width='…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=4.0, style=ProgressStyle(description_width='in…
# Epoch    12
# Train_cost  = 0.1261 | Test_cost  = 0.2208 | Train_score = 0.9605 | Test_score = 0.9339 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=14.0, style=ProgressStyle(description_width='…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=4.0, style=ProgressStyle(description_width='in…
# Epoch    13
# Train_cost  = 0.1037 | Test_cost  = 0.1240 | Train_score = 0.9708 | Test_score = 0.9544 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=14.0, style=ProgressStyle(description_width='…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=4.0, style=ProgressStyle(description_width='in…
# Epoch    14
# Train_cost  = 0.0892 | Test_cost  = 0.1225 | Train_score = 0.9748 | Test_score = 0.9636 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=14.0, style=ProgressStyle(description_width='…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=4.0, style=ProgressStyle(description_width='in…
# Epoch    15
# Train_cost  = 0.0780 | Test_cost  = 0.3754 | Train_score = 0.9754 | Test_score = 0.8702 |
# ==> EarlyStop patience =  1 | Best test_score: 0.9636
# HBox(children=(FloatProgress(value=0.0, description='Train', max=14.0, style=ProgressStyle(description_width='…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=4.0, style=ProgressStyle(description_width='in…
# Epoch    16
# Train_cost  = 0.0876 | Test_cost  = 0.1264 | Train_score = 0.9703 | Test_score = 0.9613 |
# ==> EarlyStop patience =  2 | Best test_score: 0.9636
# HBox(children=(FloatProgress(value=0.0, description='Train', max=14.0, style=ProgressStyle(description_width='…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=4.0, style=ProgressStyle(description_width='in…
# Epoch    17
# Train_cost  = 0.0791 | Test_cost  = 0.1092 | Train_score = 0.9737 | Test_score = 0.9681 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=14.0, style=ProgressStyle(description_width='…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=4.0, style=ProgressStyle(description_width='in…
# Epoch    18
# Train_cost  = 0.0619 | Test_cost  = 0.1562 | Train_score = 0.9811 | Test_score = 0.9431 |
# ==> EarlyStop patience =  1 | Best test_score: 0.9681
# HBox(children=(FloatProgress(value=0.0, description='Train', max=14.0, style=ProgressStyle(description_width='…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=4.0, style=ProgressStyle(description_width='in…
# Epoch    19
# Train_cost  = 0.0461 | Test_cost  = 0.2769 | Train_score = 0.9868 | Test_score = 0.9066 |
# ==> EarlyStop patience =  2 | Best test_score: 0.9681
# HBox(children=(FloatProgress(value=0.0, description='Train', max=14.0, style=ProgressStyle(description_width='…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=4.0, style=ProgressStyle(description_width='in…
# Epoch    20
# Train_cost  = 0.0377 | Test_cost  = 0.0952 | Train_score = 0.9886 | Test_score = 0.9636 |
# ==> EarlyStop patience =  3 | Best test_score: 0.9681
# HBox(children=(FloatProgress(value=0.0, description='Train', max=14.0, style=ProgressStyle(description_width='…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=4.0, style=ProgressStyle(description_width='in…
# Epoch    21
# Train_cost  = 0.0569 | Test_cost  = 0.2769 | Train_score = 0.9834 | Test_score = 0.9134 |
# ==> EarlyStop patience =  4 | Best test_score: 0.9681
# HBox(children=(FloatProgress(value=0.0, description='Train', max=14.0, style=ProgressStyle(description_width='…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=4.0, style=ProgressStyle(description_width='in…
# Epoch    22
# Train_cost  = 0.0570 | Test_cost  = 0.0663 | Train_score = 0.9817 | Test_score = 0.9841 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=14.0, style=ProgressStyle(description_width='…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=4.0, style=ProgressStyle(description_width='in…
# Epoch    23
# Train_cost  = 0.0390 | Test_cost  = 0.1028 | Train_score = 0.9891 | Test_score = 0.9636 |
# ==> EarlyStop patience =  1 | Best test_score: 0.9841
# HBox(children=(FloatProgress(value=0.0, description='Train', max=14.0, style=ProgressStyle(description_width='…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=4.0, style=ProgressStyle(description_width='in…
# Epoch    24
# Train_cost  = 0.0325 | Test_cost  = 0.1744 | Train_score = 0.9897 | Test_score = 0.9431 |
# ==> EarlyStop patience =  2 | Best test_score: 0.9841
# HBox(children=(FloatProgress(value=0.0, description='Train', max=14.0, style=ProgressStyle(description_width='…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=4.0, style=ProgressStyle(description_width='in…
# Epoch    25
# Train_cost  = 0.0336 | Test_cost  = 0.0525 | Train_score = 0.9897 | Test_score = 0.9863 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=14.0, style=ProgressStyle(description_width='…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=4.0, style=ProgressStyle(description_width='in…
# Epoch    26
# Train_cost  = 0.0271 | Test_cost  = 0.0448 | Train_score = 0.9909 | Test_score = 0.9932 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=14.0, style=ProgressStyle(description_width='…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=4.0, style=ProgressStyle(description_width='in…
# Epoch    27
# Train_cost  = 0.0232 | Test_cost  = 0.0465 | Train_score = 0.9920 | Test_score = 0.9909 |
# ==> EarlyStop patience =  1 | Best test_score: 0.9932
# HBox(children=(FloatProgress(value=0.0, description='Train', max=14.0, style=ProgressStyle(description_width='…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=4.0, style=ProgressStyle(description_width='in…
# Epoch    28
# Train_cost  = 0.0187 | Test_cost  = 0.1177 | Train_score = 0.9949 | Test_score = 0.9613 |
# ==> EarlyStop patience =  2 | Best test_score: 0.9932
# HBox(children=(FloatProgress(value=0.0, description='Train', max=14.0, style=ProgressStyle(description_width='…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=4.0, style=ProgressStyle(description_width='in…
# Epoch    29
# Train_cost  = 0.0420 | Test_cost  = 0.1471 | Train_score = 0.9868 | Test_score = 0.9522 |
# ==> EarlyStop patience =  3 | Best test_score: 0.9932
# HBox(children=(FloatProgress(value=0.0, description='Train', max=14.0, style=ProgressStyle(description_width='…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=4.0, style=ProgressStyle(description_width='in…
# Epoch    30
# Train_cost  = 0.0276 | Test_cost  = 0.0476 | Train_score = 0.9897 | Test_score = 0.9909 |
# ==> EarlyStop patience =  4 | Best test_score: 0.9932
# HBox(children=(FloatProgress(value=0.0, description='Train', max=14.0, style=ProgressStyle(description_width='…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=4.0, style=ProgressStyle(description_width='in…
# Epoch    31
# Train_cost  = 0.0209 | Test_cost  = 0.0693 | Train_score = 0.9931 | Test_score = 0.9749 |
# ==> EarlyStop patience =  5 | Best test_score: 0.9932
# ==> Execute Early Stopping at epoch: 31 | Best test_score: 0.9932
# ==> Best model is saved at model

# %% [markdown]
# # Prediction

# %%
feature, target = next(iter(testloader))
feature, target = feature.to(device), target.to(device)

# %%
with torch.no_grad():
    model.eval()
    output = model(feature)
    preds = output.argmax(1)
preds
# Out:
# tensor([2, 2, 0, 1, 0, 1, 0, 1, 1, 2, 1, 2, 2, 0, 0, 0, 1, 2, 2, 2, 0, 0, 0, 1,
#         0, 0, 1, 0, 2, 2, 0, 1, 2, 2, 0, 0, 0, 0, 0, 2, 2, 0, 2, 0, 0, 0, 1, 2,
#         2, 0, 1, 0, 2, 2, 2, 2, 0, 2, 0, 1, 1, 1, 1, 2, 0, 2, 1, 2, 0, 0, 2, 2,
#         0, 1, 1, 2, 2, 1, 2, 0, 0, 2, 0, 0, 0, 0, 1, 2, 2, 1, 1, 2, 2, 2, 2, 1,
#         1, 0, 1, 1, 0, 2, 1, 2, 2, 0, 2, 1, 1, 2, 0, 0, 0, 1, 2, 2, 0, 0, 0, 1,
#         1, 0, 2, 1, 2, 2, 2, 1], device='cuda:0')

# %%
import matplotlib.pyplot as plt

# %%
fig, axes = plt.subplots(6, 6, figsize=(24, 24))
for image, label, pred, ax in zip(feature, target, preds, axes.flatten()):
    ax.imshow(image.permute(1, 2, 0).cpu())
    font = {"color": 'r'} if label != pred else {"color": 'g'}        
    label, pred = train_set.classes[label.item()], train_set.classes[pred.item()]
    ax.set_title(f"L: {label} | P: {pred}", fontdict=font);
    ax.axis('off');
